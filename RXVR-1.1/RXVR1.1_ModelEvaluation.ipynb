# %% [markdown]
# # `xvr` tutorial
#
# 1. Connect to a GPU: `Runtime > Change runtime type > T4 GPU`
# 2. Install `xvr`
# 3. Download data and pretrained models

# %%
# !pip install git+https://github.com/eigenvivek/xvr.git --upgrade
# Out:
# Collecting git+https://github.com/eigenvivek/xvr.git
#   Cloning https://github.com/eigenvivek/xvr.git to c:\users\aksha\appdata\local\temp\pip-req-build-3kkwxw7y
#   Resolved https://github.com/eigenvivek/xvr.git to commit af8287cd6d8cf0bad4cb07d746a5fff7b1eeaecb
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: wandb>=0.19.8 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from xvr==0.0.0rc1) (0.21.0)
# Requirement already satisfied: antspyx>=0.5.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from xvr==0.0.0rc1) (0.6.1)
# Requirement already satisfied: click>=8.1.8 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from xvr==0.0.0rc1) (8.2.1)
# Requirement already satisfied: pydicom[pixeldata]>=3.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from xvr==0.0.0rc1) (3.0.1)
# Requirement already satisfied: diffdrr>=0.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from xvr==0.0.0rc1) (0.6.0rc2)
# Requirement already satisfied: requests in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (2.32.4)
# Requirement already satisfied: pandas in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (2.3.1)
# Requirement already satisfied: scipy<1.16 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (1.15.3)
# Requirement already satisfied: webcolors in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (24.11.1)
# Requirement already satisfied: statsmodels in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (0.14.5)
# Requirement already satisfied: Pillow in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (11.0.0)
# Requirement already satisfied: scikit-learn in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (1.7.1)
# Requirement already satisfied: pyyaml in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (6.0.2)
# Requirement already satisfied: matplotlib in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (3.10.3)
# Requirement already satisfied: numpy in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from antspyx>=0.5.4->xvr==0.0.0rc1) (2.1.2)
# Requirement already satisfied: colorama in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.8->xvr==0.0.0rc1) (0.4.6)
# Requirement already satisfied: seaborn in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (0.13.2)
# Requirement already satisfied: tqdm in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (4.67.1)
# Requirement already satisfied: imageio in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (2.37.0)
# Requirement already satisfied: fastcore in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (1.8.5)
# Requirement already satisfied: pyvista[all] in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (0.45.3)
# Requirement already satisfied: einops in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (0.8.1)
# Requirement already satisfied: torchvision in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (0.20.1+cu121)
# Requirement already satisfied: torchio in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (0.20.18)
# Requirement already satisfied: timm in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (1.0.17)
# Requirement already satisfied: kornia in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (0.8.1)
# Requirement already satisfied: torch in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr>=0.5.0->xvr==0.0.0rc1) (2.5.1+cu121)
# Requirement already satisfied: python-gdcm in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pydicom[pixeldata]>=3.0.1->xvr==0.0.0rc1) (3.0.26)
# Requirement already satisfied: pyjpegls in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pydicom[pixeldata]>=3.0.1->xvr==0.0.0rc1) (1.5.1)
# Requirement already satisfied: pylibjpeg[rle] in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pydicom[pixeldata]>=3.0.1->xvr==0.0.0rc1) (2.0.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (6.31.1)
# Requirement already satisfied: platformdirs in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (4.3.8)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (2.33.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (3.1.44)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (4.14.1)
# Requirement already satisfied: packaging in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (25.0)
# Requirement already satisfied: pydantic<3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wandb>=0.19.8->xvr==0.0.0rc1) (2.11.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.19.8->xvr==0.0.0rc1) (4.0.12)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3->wandb>=0.19.8->xvr==0.0.0rc1) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3->wandb>=0.19.8->xvr==0.0.0rc1) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3->wandb>=0.19.8->xvr==0.0.0rc1) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->antspyx>=0.5.4->xvr==0.0.0rc1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->antspyx>=0.5.4->xvr==0.0.0rc1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->antspyx>=0.5.4->xvr==0.0.0rc1) (2025.7.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->antspyx>=0.5.4->xvr==0.0.0rc1) (2.5.0)
# Requirement already satisfied: kornia_rs>=0.1.9 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from kornia->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.1.9)
# Requirement already satisfied: jinja2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.1.3)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.13.1)
# Requirement already satisfied: filelock in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.18.0)
# Requirement already satisfied: fsspec in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (2024.6.1)
# Requirement already satisfied: networkx in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (3.2.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (1.4.8)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pandas->antspyx>=0.5.4->xvr==0.0.0rc1) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pandas->antspyx>=0.5.4->xvr==0.0.0rc1) (2025.2)
# Requirement already satisfied: pylibjpeg-openjpeg in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pylibjpeg[rle]->pydicom[pixeldata]>=3.0.1->xvr==0.0.0rc1) (2.4.0)
# Requirement already satisfied: pylibjpeg-rle in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pylibjpeg[rle]->pydicom[pixeldata]>=3.0.1->xvr==0.0.0rc1) (2.1.0)
# Requirement already satisfied: vtk<9.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (9.4.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.10.1)
# Requirement already satisfied: pooch in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.8.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->antspyx>=0.5.4->xvr==0.0.0rc1) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->antspyx>=0.5.4->xvr==0.0.0rc1) (1.5.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from statsmodels->antspyx>=0.5.4->xvr==0.0.0rc1) (1.0.1)
# Requirement already satisfied: huggingface_hub in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from timm->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.33.4)
# Requirement already satisfied: safetensors in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from timm->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.5.3)
# Requirement already satisfied: rich>=10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (14.0.0)
# Requirement already satisfied: simpleitk!=2.0.*,!=2.1.1.1,>=1.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.5.2)
# Requirement already satisfied: typer>=0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.16.0)
# Requirement already satisfied: nibabel>=3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.3.2)
# Requirement already satisfied: deprecated>=1.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.2.18)
# Requirement already satisfied: humanize>=0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.12.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from deprecated>=1.2->torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.19.8->xvr==0.0.0rc1) (5.0.2)
# Requirement already satisfied: importlib-resources>=5.12 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nibabel>=3->torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (6.5.2)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->antspyx>=0.5.4->xvr==0.0.0rc1) (1.17.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from rich>=10->torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from rich>=10->torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.1->torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.1.5)
# Requirement already satisfied: trame-vtk>=2.5.8 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.9.0)
# Requirement already satisfied: trame-server>=2.11.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.5.0)
# Requirement already satisfied: trame>=2.5.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.10.2)
# Requirement already satisfied: jupyter-server-proxy in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.4.0)
# Requirement already satisfied: trame-client>=2.12.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.9.1)
# Requirement already satisfied: ipywidgets in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (8.1.7)
# Requirement already satisfied: nest_asyncio in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.6.0)
# Requirement already satisfied: trame-vuetify>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.0.1)
# Requirement already satisfied: cmocean in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.0.3)
# Requirement already satisfied: colorcet in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.1.0)
# Requirement already satisfied: meshio>=5.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.3.5)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10->torchio->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.1.2)
# Requirement already satisfied: trame-common<2,>=1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from trame>=2.5.2->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.0.0)
# Requirement already satisfied: wslink>=2.3.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from trame>=2.5.2->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.3.4)
# Requirement already satisfied: more-itertools in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from trame-server>=2.11.7->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (10.7.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.14.3)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.0.15)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.0.14)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (8.37.0)
# Requirement already satisfied: simpervisor>=1.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.0.0)
# Requirement already satisfied: jupyter-server>=1.24.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.16.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (6.5.1)
# Requirement already satisfied: aiohttp in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.12.14)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.0.51)
# Requirement already satisfied: jedi>=0.16 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.19.2)
# Requirement already satisfied: exceptiongroup in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.3.0)
# Requirement already satisfied: stack_data in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.6.3)
# Requirement already satisfied: decorator in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.2.1)
# Requirement already satisfied: matplotlib-inline in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.1.7)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.10.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.9.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.12.0)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.8.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.8.3)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (8.6.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (7.16.6)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.22.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (25.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.18.1)
# Requirement already satisfied: pyzmq>=24 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (27.0.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.5.3)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.0.15)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.8.1)
# Requirement already satisfied: overrides>=5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (7.7.0)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wslink>=2.3.3->trame>=2.5.2->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.1.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (25.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (6.6.3)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.20.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.8.4)
# Requirement already satisfied: pywin32>=300 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (311)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.1.1)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.24.1)
# Requirement already satisfied: rfc3339-validator in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.1.4)
# Requirement already satisfied: referencing in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.36.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.3.0)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (6.2.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.3.0)
# Requirement already satisfied: defusedxml in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.5.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.10.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (4.13.4)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.1.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.2.13)
# Requirement already satisfied: pure-eval in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.0.0)
# Requirement already satisfied: webencodings in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.4.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (0.26.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2025.4.1)
# Requirement already satisfied: fqdn in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (20.11.0)
# Requirement already satisfied: uri-template in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (3.0.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.7)
# Requirement already satisfied: pycparser in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr>=0.5.0->xvr==0.0.0rc1) (2.9.0.20250708)
#   Running command git clone --filter=blob:none --quiet https://github.com/eigenvivek/xvr.git 'C:\Users\aksha\AppData\Local\Temp\pip-req-build-3kkwxw7y'
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install git+https://github.com/eigenvivek/DiffDRR.git

# !pip install nibabel pydicom matplotlib tqdm
# Out:
# Collecting git+https://github.com/eigenvivek/DiffDRR.git
#   Cloning https://github.com/eigenvivek/DiffDRR.git to c:\users\aksha\appdata\local\temp\pip-req-build-68a_jycw
#   Resolved https://github.com/eigenvivek/DiffDRR.git to commit 13a9a224db3005348f174a349aea9774d500aac5
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (3.10.3)
# Requirement already satisfied: seaborn in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (0.13.2)
# Requirement already satisfied: tqdm in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (4.67.1)
# Requirement already satisfied: imageio in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (2.37.0)
# Requirement already satisfied: fastcore in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (1.8.5)
# Requirement already satisfied: pyvista[all] in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (0.45.3)
# Requirement already satisfied: einops in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (0.8.1)
# Requirement already satisfied: torchvision in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (0.20.1+cu121)
# Requirement already satisfied: scipy in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (1.15.3)
# Requirement already satisfied: torchio in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (0.20.18)
# Requirement already satisfied: timm in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (1.0.17)
# Requirement already satisfied: numpy in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (2.1.2)
# Requirement already satisfied: kornia in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (0.8.1)
# Requirement already satisfied: torch in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from diffdrr==0.6.0rc2) (2.5.1+cu121)
# Requirement already satisfied: packaging in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from fastcore->diffdrr==0.6.0rc2) (25.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from imageio->diffdrr==0.6.0rc2) (11.0.0)
# Requirement already satisfied: kornia_rs>=0.1.9 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from kornia->diffdrr==0.6.0rc2) (0.1.9)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr==0.6.0rc2) (1.13.1)
# Requirement already satisfied: fsspec in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr==0.6.0rc2) (2024.6.1)
# Requirement already satisfied: jinja2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr==0.6.0rc2) (3.1.3)
# Requirement already satisfied: filelock in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr==0.6.0rc2) (3.18.0)
# Requirement already satisfied: networkx in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr==0.6.0rc2) (3.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torch->diffdrr==0.6.0rc2) (4.14.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from sympy==1.13.1->torch->diffdrr==0.6.0rc2) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->diffdrr==0.6.0rc2) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->diffdrr==0.6.0rc2) (4.59.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->diffdrr==0.6.0rc2) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->diffdrr==0.6.0rc2) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->diffdrr==0.6.0rc2) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->diffdrr==0.6.0rc2) (3.2.3)
# Requirement already satisfied: pooch in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (1.8.2)
# Requirement already satisfied: vtk!=9.4.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (9.4.2)
# Requirement already satisfied: scooby>=0.5.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (0.10.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from seaborn->diffdrr==0.6.0rc2) (2.3.1)
# Requirement already satisfied: safetensors in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from timm->diffdrr==0.6.0rc2) (0.5.3)
# Requirement already satisfied: huggingface_hub in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from timm->diffdrr==0.6.0rc2) (0.33.4)
# Requirement already satisfied: pyyaml in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from timm->diffdrr==0.6.0rc2) (6.0.2)
# Requirement already satisfied: humanize>=0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr==0.6.0rc2) (4.12.3)
# Requirement already satisfied: typer>=0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr==0.6.0rc2) (0.16.0)
# Requirement already satisfied: nibabel>=3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr==0.6.0rc2) (5.3.2)
# Requirement already satisfied: rich>=10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr==0.6.0rc2) (14.0.0)
# Requirement already satisfied: simpleitk!=2.0.*,!=2.1.1.1,>=1.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr==0.6.0rc2) (2.5.2)
# Requirement already satisfied: deprecated>=1.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from torchio->diffdrr==0.6.0rc2) (1.2.18)
# Requirement already satisfied: colorama in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from tqdm->diffdrr==0.6.0rc2) (0.4.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from deprecated>=1.2->torchio->diffdrr==0.6.0rc2) (1.17.2)
# Requirement already satisfied: importlib-resources>=5.12 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nibabel>=3->torchio->diffdrr==0.6.0rc2) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn->diffdrr==0.6.0rc2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn->diffdrr==0.6.0rc2) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->diffdrr==0.6.0rc2) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from rich>=10->torchio->diffdrr==0.6.0rc2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from rich>=10->torchio->diffdrr==0.6.0rc2) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.1->torchio->diffdrr==0.6.0rc2) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.1->torchio->diffdrr==0.6.0rc2) (1.5.4)
# Requirement already satisfied: requests in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from huggingface_hub->timm->diffdrr==0.6.0rc2) (2.32.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch->diffdrr==0.6.0rc2) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pooch->pyvista[all]->diffdrr==0.6.0rc2) (4.3.8)
# Requirement already satisfied: meshio>=5.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (5.3.5)
# Requirement already satisfied: cmocean in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (4.0.3)
# Requirement already satisfied: colorcet in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (3.1.0)
# Requirement already satisfied: jupyter-server-proxy in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (4.4.0)
# Requirement already satisfied: nest_asyncio in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (1.6.0)
# Requirement already satisfied: ipywidgets in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (8.1.7)
# Requirement already satisfied: trame-client>=2.12.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (3.9.1)
# Requirement already satisfied: trame-vtk>=2.5.8 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (2.9.0)
# Requirement already satisfied: trame-vuetify>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (3.0.1)
# Requirement already satisfied: trame-server>=2.11.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (3.5.0)
# Requirement already satisfied: trame>=2.5.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from pyvista[all]->diffdrr==0.6.0rc2) (3.10.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10->torchio->diffdrr==0.6.0rc2) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub->timm->diffdrr==0.6.0rc2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub->timm->diffdrr==0.6.0rc2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub->timm->diffdrr==0.6.0rc2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface_hub->timm->diffdrr==0.6.0rc2) (2025.7.14)
# Requirement already satisfied: trame-common<2,>=1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from trame>=2.5.2->pyvista[all]->diffdrr==0.6.0rc2) (1.0.0)
# Requirement already satisfied: wslink>=2.3.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from trame>=2.5.2->pyvista[all]->diffdrr==0.6.0rc2) (2.3.4)
# Requirement already satisfied: more-itertools in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from trame-server>=2.11.7->pyvista[all]->diffdrr==0.6.0rc2) (10.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (4.0.14)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (8.37.0)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (3.0.15)
# Requirement already satisfied: comm>=0.1.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (5.14.3)
# Requirement already satisfied: jupyter-server>=1.24.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.16.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (6.5.1)
# Requirement already satisfied: aiohttp in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (3.12.14)
# Requirement already satisfied: simpervisor>=1.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.0.0)
# Requirement already satisfied: decorator in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (5.2.1)
# Requirement already satisfied: matplotlib-inline in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.1.7)
# Requirement already satisfied: exceptiongroup in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (1.3.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (3.0.51)
# Requirement already satisfied: stack_data in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.6.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.19.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.12.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (5.10.4)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.8.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (4.9.0)
# Requirement already satisfied: overrides>=5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (7.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (8.6.3)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.5.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.18.1)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (7.16.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (5.8.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.8.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.0.15)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.22.1)
# Requirement already satisfied: pyzmq>=24 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (27.0.0)
# Requirement already satisfied: msgpack<2,>=1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from wslink>=2.3.3->trame>=2.5.2->pyvista[all]->diffdrr==0.6.0rc2) (1.1.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.3.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (6.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (25.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.20.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (5.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.8.4)
# Requirement already satisfied: pywin32>=300 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (311)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.1.1)
# Requirement already satisfied: rfc3339-validator in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.1.4)
# Requirement already satisfied: referencing in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.36.2)
# Requirement already satisfied: jsonschema[format-nongpl]>=4.18.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (4.24.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (3.3.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (4.13.4)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (3.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.5.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.10.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.2.13)
# Requirement already satisfied: pure-eval in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->pyvista[all]->diffdrr==0.6.0rc2) (2.2.0)
# Requirement already satisfied: webencodings in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (0.26.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.3.0)
# Requirement already satisfied: isoduration in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (20.11.0)
# Requirement already satisfied: fqdn in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.5.1)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.7)
# Requirement already satisfied: pycparser in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->pyvista[all]->diffdrr==0.6.0rc2) (2.9.0.20250708)
#   Running command git clone --filter=blob:none --quiet https://github.com/eigenvivek/DiffDRR.git 'C:\Users\aksha\AppData\Local\Temp\pip-req-build-68a_jycw'
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nibabel in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (5.3.2)
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pydicom in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (3.0.1)
# Requirement already satisfied: matplotlib in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: tqdm in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (4.67.1)
# Requirement already satisfied: importlib-resources>=5.12 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nibabel) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nibabel) (4.14.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nibabel) (2.1.2)
# Requirement already satisfied: packaging>=20 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from nibabel) (25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: colorama in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# ## Install `xvr`

# %%
# !xvr --version
# Out:
# xvr, version 0.0.0rc1

# %% [markdown]
# ## Test-time optimization
#
# Here, we show how to iteratively refine the initial poses estimated by a patient-specific neural network.

# %%
# !HF_HUB_DISABLE_PROGRESS_BARS=TRUE
# Out:
# 'HF_HUB_DISABLE_PROGRESS_BARS' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import torch
from diffdrr.pose import RigidTransform
from huggingface_hub import snapshot_download

from xvr.metrics import Evaluator
from xvr.registrar import RegistrarModel
from xvr.utils import XrayTransforms
from xvr.visualization import plot_registration

# %%
import matplotlib.pyplot as plt
import torch
from diffdrr.visualization import plot_drr
from xvr.metrics import Evaluator
from xvr.utils import XrayTransforms
from diffdrr.pose import RigidTransform

def plot_registration(drr, fiducials, gt, pred_pose, true_pose):
    """
    Visualize registration results:
    - Uses unflipped pred_pose for DRR rendering (ensures valid image)
    - Uses flipped pred_pose for fiducial projection and mTRE calculation (ensures alignment)
    """
    # Step 1: Flip a copy of the predicted pose for fiducial projection & evaluation
    flipped_pose = RigidTransform(matrix=pred_pose.matrix.clone())
    # flipped_pose.matrix[0, 0, 3] *= -1  # Flip X translation
    flipped_pose.matrix[0, 1, 3] *= -1  # Flip Y translation
    # flipped_pose.matrix[0, 2, 3] *= -1  # Flip Z translation


    # Step 2: Evaluate mTRE using pose
    evaluator = Evaluator(drr, fiducials)
    mtre = evaluator(true_pose, flipped_pose)[2]

    # Step 3: Generate DRRs and project fiducials
    with torch.no_grad():
        pred_img = drr(pred_pose).cpu()
        true_img = drr(true_pose).cpu()
        error = (true_img - pred_img)

        pred_pts = drr.perspective_projection(flipped_pose, fiducials).cpu().squeeze()
        true_pts = drr.perspective_projection(true_pose, fiducials).cpu().squeeze()

    xt = XrayTransforms(drr.detector.height, drr.detector.width)
    gt = xt(gt)
    pred_img = xt(pred_img)

    axs = plot_drr(torch.concat([pred_img, gt, error]))

    axs[1].scatter(true_pts[..., 0], true_pts[..., 1], color="dodgerblue", label="True")
    axs[1].scatter(pred_pts[..., 0], pred_pts[..., 1], color="darkorange", label="Pred")
    for x, y in zip(pred_pts, true_pts):
        axs[1].plot([x[0], y[0]], [x[1], y[1]], "w--", linewidth=0.8)
    axs[1].legend()

    plot_drr(
        torch.concat([pred_img, gt, error]),
        title=[
            "DRR from Predicted Pose",
            "Ground truth X-ray",
            f"Error (mTRE = {mtre:.2f} mm)"
        ],
        ticks=False,
        axs=axs,
    )

    axs[2].imshow(
        error[0].permute(1, 2, 0),
        cmap="bwr",
        vmin=-error.abs().max(),
        vmax=error.abs().max()
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Evaluating pretrained models
#
# Here, we are using the pretrained models and testing them using our Femur CT data and x ray image to find the pose value.

# %%
import pandas as pd
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# ## Model Evaluation

# %%
true_pose = torch.load("Results/Trained/980x980/xray_pose.pt", weights_only=False).cuda()

print("True Pose:",true_pose.matrix)
# Out:
# True Pose: tensor([[[  1.,   0.,   0.,   0.],
#          [  0.,   1.,   0., 850.],
#          [  0.,   0.,   1., 150.],
#          [  0.,   0.,   0.,   1.]]], device='cuda:0')

# %%
import torch
import numpy as np
from scipy.spatial.transform import Rotation as Rsc

def matrix_to_euler_and_translation(pose_matrix: torch.Tensor, convention="ZXY", degrees=True):
    """
    Converts a 4x4 homogeneous pose matrix to Euler angles and translation vector.

    Args:
        pose_matrix (torch.Tensor): shape [4, 4] or [1, 4, 4]
        convention (str): e.g., "ZXY"
        degrees (bool): Return angles in degrees (True) or radians (False)

    Returns:
        euler_angles (torch.Tensor): shape [3] (rx, ry, rz)
        translation (torch.Tensor): shape [3] (x, y, z)
    """
    if pose_matrix.ndim == 3:
        pose_matrix = pose_matrix.squeeze(0)

    # Extract rotation and translation
    R_mat = pose_matrix[:3, :3].cpu().numpy()
    t_vec = pose_matrix[:3, 3].cpu()

    # Convert rotation matrix to Euler angles
    rot = Rsc.from_matrix(R_mat)
    angles = rot.as_euler(convention.lower(), degrees=degrees)
    angles_tensor = torch.tensor(angles, dtype=torch.float32)

    return angles_tensor, t_vec

# Get Euler angles and translation
euler_angles, translation = matrix_to_euler_and_translation(true_pose.matrix, convention="ZXY", degrees=True)
print("Rotation angles (ZXY) in degrees:", euler_angles)
print("Translation (mm):", translation)
# Out:
# Rotation angles (ZXY) in degrees: tensor([0., 0., 0.])
# Translation (mm): tensor([  0., 850., 150.])

# %%
# Load the ground truth 3D fiducials
fiducials = torch.load("Results/Trained/980x980/xray_fiducials.pt", weights_only=False).cuda()
# fiducials = fiducials.unsqueeze(0)  # Adds a batch dimension at dim=0

# %%
print("Fiducials",fiducials)
# Out:
# Fiducials tensor([[[-4.3840e+01, -1.5000e+02,  9.8949e+01],
#          [-4.6752e+01, -1.5000e+02,  1.0935e+02],
#          [-3.7183e+01, -1.5000e+02,  1.2557e+02],
#          [-3.0111e+01, -1.5000e+02,  8.8549e+01],
#          [-5.9823e+00, -1.5000e+02,  9.8949e+01],
#          [-2.7199e+01, -1.5000e+02,  1.0769e+02],
#          [-1.1390e+01, -1.5000e+02,  1.2225e+02],
#          [-1.8463e+01, -1.5000e+02,  1.3181e+02],
#          [-3.0701e+00, -1.5000e+02,  1.0893e+02],
#          [ 2.2307e+01, -1.5000e+02,  1.0602e+02],
#          [ 1.1490e+01, -1.5000e+02,  1.1226e+02],
#          [ 1.0658e+01, -1.5000e+02,  1.1725e+02],
#          [ 9.4103e+00, -1.5000e+02,  1.1975e+02],
#          [-1.8047e+01, -1.5000e+02,  1.5927e+02],
#          [ 3.1459e+01, -1.5000e+02,  1.3473e+02],
#          [ 2.6883e+01, -1.5000e+02,  1.1725e+02],
#          [-2.6541e+00, -1.5000e+02,  1.4055e+02],
#          [ 3.5861e+00, -1.5000e+02,  1.6302e+02],
#          [ 2.3380e+00, -1.5000e+02,  1.9380e+02],
#          [ 2.3380e+00, -1.5000e+02,  2.2500e+02],
#          [ 2.3380e+00, -1.5000e+02,  2.5204e+02],
#          [-1.5804e-01, -1.5000e+02,  2.7783e+02],
#          [-1.5804e-01, -1.5000e+02,  2.7783e+02],
#          [ 2.5797e-01, -1.5000e+02,  2.9739e+02],
#          [-9.7264e+00, -1.5000e+02,  2.9697e+02],
#          [-8.8944e+00, -1.5000e+02,  2.6785e+02],
#          [-5.9823e+00, -1.5000e+02,  2.3748e+02],
#          [-4.7342e+00, -1.5000e+02,  2.0919e+02],
#          [-5.9823e+00, -1.5000e+02,  1.8007e+02],
#          [ 1.4818e+01, -1.5000e+02,  1.7799e+02],
#          [ 1.3986e+01, -1.5000e+02,  2.0462e+02],
#          [ 1.3154e+01, -1.5000e+02,  2.3207e+02],
#          [ 1.1490e+01, -1.5000e+02,  2.6494e+02],
#          [ 9.8263e+00, -1.5000e+02,  2.8865e+02]]], device='cuda:0')

# %%
import pydicom
import matplotlib.pyplot as plt
from pathlib import Path

dicom_img = pydicom.dcmread("Results/Trained/980x980/xray_image.dcm")

# Print metadata
print(dicom_img)

# Display the image
plt.imshow(dicom_img.pixel_array, cmap='gray')
plt.title("Frontal X-ray")
plt.axis('off')
plt.show()
# Out:
# Dataset.file_meta -------------------------------
# (0002,0002) Media Storage SOP Class UID         UI: X-Ray Angiographic Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.8.498.50568109045326789714718063247338005418
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.8.498.1
# (0002,0013) Implementation Version Name         SH: 'PYDICOM 2.4.4'
# -------------------------------------------------
# (0008,0016) SOP Class UID                       UI: X-Ray Angiographic Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.8.498.50568109045326789714718063247338005418
# (0008,0020) Study Date                          DA: '20250725'
# (0008,0030) Study Time                          TM: '124539'
# (0008,0060) Modality                            CS: 'OT'
# (0010,0010) Patient's Name                      PN: 'Synthetic'
# (0010,0020) Patient ID                          LO: '123456'
# (0018,1110) Distance Source to Detector         DS: '1000.0000000000'
# (0018,7028) Detector Active Origin              DS: [0.0000000000, 0.0000000000]
# (0020,000D) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.59343419795369720181268826382817163037
# (0020,000E) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.82641530877367587251865845845990998649
# (0028,0002) Samples per Pixel                   US: 1
# (0028,0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028,0010) Rows                                US: 980
# (0028,0011) Columns                             US: 980
# (0028,0030) Pixel Spacing                       DS: [0.3160816327, 0.3160816327]
# (0028,0100) Bits Allocated                      US: 16
# (0028,0101) Bits Stored                         US: 16
# (0028,0102) High Bit                            US: 15
# (0028,0103) Pixel Representation                US: 0
# (0028,1050) Window Center                       DS: '32896.0'
# (0028,1051) Window Width                        DS: '65535.0'
# (7FE0,0010) Pixel Data                          OW: Array of 1920800 elements

# %%
model_agnostic = RegistrarModel(
        volume="SE000002.nii.gz",
        mask=None,
        # ckptpath="trained-new-paths/finetuned02_10ep.pth",
        # ckptpath = "/content/drive/MyDrive/Trained Registration model/Finetuned/Agnostic Fine tuned Default Parameter/xvr_0005.pth", # Best for full bone
        ckptpath = "output_trained\RXVR1.1_best.pth",
        crop=0,
        init_only=False,
    )

# %%
# import pydicom

# # Load your C-arm DICOM file
# filename = "C_Arm/1.2.840.113780.9800.8251012.20250716145723.3.40.dcm"  # Update this path if needed
# ds = pydicom.dcmread(filename)

# # Set the missing attribute
# ds.DistanceSourceToDetector = 1000  # Replace 1000 with your actual sdd value in mm

# # Optional: make sure PixelSpacing is present and valid
# if "PixelSpacing" not in ds:
#     ds.PixelSpacing = [0.316, 0.316]  # based on your delx

# # Save the updated DICOM
# ds.save_as(filename)
# print("DICOM updated with SDD and saved.")

# %%
# print(ds.DistanceSourceToDetector)
# print(ds.PixelSpacing)

# %%
# Demonstrate the patient-agnostic model
gt, _, drr, init_pose, final_pose, _ = model_agnostic.run("Results/Trained/980x980/xray_image.dcm", beta=0.5)
# Out:
# Stage 1:  18%|███████▎                                | 91/500 [00:01<00:08, 46.41it/s, ncc = 0.304]

# %%
print("Initial Pose:",init_pose.matrix)
print(type(init_pose))
# Out:
# Initial Pose: tensor([[[ 7.8077e-01,  6.0931e-01,  1.3835e-01, -3.9727e+02],
#          [-6.2161e-01,  7.7991e-01,  7.3164e-02, -5.2642e+02],
#          [-6.3321e-02, -1.4312e-01,  9.8768e-01,  2.3732e+02],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        device='cuda:0')
# <class 'diffdrr.pose.RigidTransform'>

# %%
print("Final Pose:",final_pose.matrix)
print(type(final_pose))
# Out:
# Final Pose: tensor([[[ 8.0524e-01,  5.9129e-01,  4.4306e-02, -4.1136e+02],
#          [-5.9022e-01,  8.0645e-01, -3.5643e-02, -5.7974e+02],
#          [-5.6806e-02,  2.5509e-03,  9.9838e-01,  1.4886e+02],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  1.0000e+00]]],
#        device='cuda:0', grad_fn=<CopySlices>)
# <class 'diffdrr.pose.RigidTransform'>

# %%
from scipy.spatial.transform import Rotation as Rsc

def matrix_to_euler_and_translation(pose_matrix: torch.Tensor, convention="ZXY", degrees=True):
    if pose_matrix.ndim == 3:
        pose_matrix = pose_matrix.squeeze(0)

    # Extract rotation and translation
    R_mat = pose_matrix[:3, :3].cpu().numpy()
    t_vec = pose_matrix[:3, 3].cpu()

    # Convert rotation matrix to Euler angles
    rot = Rsc.from_matrix(R_mat)
    angles = rot.as_euler(convention.lower(), degrees=degrees)
    angles_tensor = torch.tensor(angles, dtype=torch.float32)

    return angles_tensor, t_vec

# Get Euler angles and translation
euler_angles, translation = matrix_to_euler_and_translation(init_pose.matrix, convention="ZXY", degrees=True)
# Output
print("Predicted 6 DOF Initial Pose of the X-Ray image")
print("Rotation angles (ZXY) in degrees:", euler_angles)
print("Translation (mm):", translation)
# Out:
# Predicted 6 DOF Initial Pose of the X-Ray image
# Rotation angles (ZXY) in degrees: tensor([-38.5558,  -4.1957,   7.9739])
# Translation (mm): tensor([-397.2747, -526.4176,  237.3242])

# %%
from scipy.spatial.transform import Rotation as Rsc

def matrix_to_euler_and_translation(pose_matrix: torch.Tensor, convention="ZXY", degrees=True):
    if pose_matrix.ndim == 3:
        pose_matrix = pose_matrix.squeeze(0)

    # Extract rotation and translation
    R_mat = pose_matrix[:3, :3].detach().cpu().numpy()
    t_vec = pose_matrix[:3, 3].detach().cpu()

    # Convert rotation matrix to Euler angles
    rot = Rsc.from_matrix(R_mat)
    angles = rot.as_euler(convention.lower(), degrees=degrees)
    angles_tensor = torch.tensor(angles, dtype=torch.float32)

    return angles_tensor, t_vec

# Get Euler angles and translation
euler_angles, translation = matrix_to_euler_and_translation(final_pose.matrix, convention="ZXY", degrees=True)
# Output
print("Predicted 6 DOF Final Pose of the X-Ray image")
print("Rotation angles (ZXY) in degrees:", euler_angles)
print("Translation (mm):", translation)
# Out:
# Predicted 6 DOF Final Pose of the X-Ray image
# Rotation angles (ZXY) in degrees: tensor([-36.1993,   2.0426,   2.5410])
# Translation (mm): tensor([-411.3646, -579.7428,  148.8634])

# %%
plot_registration(drr, fiducials, gt, init_pose, true_pose)

# %%
plot_registration(drr, fiducials, gt, final_pose, true_pose)
