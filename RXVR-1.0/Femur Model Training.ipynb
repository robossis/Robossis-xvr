# %%
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# !pip install wandb nibabel torchio tqdm fastcore
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 104.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 55.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 123.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 41.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/eigenvivek/xvr.git
# %cd xvr

# !pip install git+https://github.com/eigenvivek/xvr.git
# Out:
# Cloning into 'xvr'...
# remote: Enumerating objects: 414, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 414 (delta 87), reused 116 (delta 55), pack-reused 242 (from 2)
# Receiving objects: 100% (414/414), 2.01 MiB | 27.48 MiB/s, done.
# Resolving deltas: 100% (185/185), done.
# /content/xvr
# ...
#   Cloning https://github.com/eigenvivek/xvr.git to /tmp/pip-req-build-qjf23oqj
#   Running command git clone --filter=blob:none --quiet https://github.com/eigenvivek/xvr.git /tmp/pip-req-build-qjf23oqj
#   Resolved https://github.com/eigenvivek/xvr.git to commit af8287cd6d8cf0bad4cb07d746a5fff7b1eeaecb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 78.1 MB/s eta 0:00:00
# ...

# %%
import torch
import torchvision
import torchaudio
import nibabel as nib
import torchio
import tqdm
import wandb

# Check CUDA availability and GPU info
print("Torch CUDA available:", torch.cuda.is_available())
print("Torch version:", torch.__version__)
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
    print("CUDA Version:", torch.version.cuda)

# Checking xvr import
try:
    import xvr
    print("✅ xvr imported successfully")
except ImportError as e:
    print("❌ xvr import failed:", e)
# Out:
# Torch CUDA available: True
# Torch version: 2.7.1+cu118
# GPU Name: NVIDIA A100-SXM4-40GB
# CUDA Version: 11.8
# ✅ xvr imported successfully

# %%
import os
os.kill(os.getpid(), 9)

# %%
import gc

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
gc.collect()
# Out:
# 0

# %%
# !nvidia-smi
# Out:
# Wed Jun 25 13:57:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             47W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import os
os.environ["WANDB_API_KEY"] = "524773117955f64051f5e2bd2ecef2642a677a34"

# %%
# Fixing wandb login
# !sed -i 's/wandb.login(key=os.environ\["WANDB_API_KEY"\])/wandb.login()/' /usr/local/lib/python3.*/dist-packages/xvr/commands/train.py

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
gc.collect()

#Training the model with a single femur CT Volume.

# !xvr train \
  -i "/content/drive/MyDrive/SE000002.nii" \
  -o "/content/drive/MyDrive/Trained Registration model/Scratch" \
  --r1 -45 45 \
  --r2 -45 45 \
  --r3 -15 15 \
  --tx -150 150 \
  --ty -1000 -400 \
  --tz -150 200 \
  --sdd 1020 \
  --height 256 \
  --delx 0.310547 \
  --renderer trilinear \
  --parameterization euler_angles \
  --convention ZXY \
  --model_name resnet18 \
  --pretrained \
  --batch_size 32 \
  --n_epochs 1000 \
  --n_batches_per_epoch 100 \
  --reverse_x_axis \
  --name patient_se000002_longtrain \
  --project pose_regression
# Out:
# wandb: Currently logged in as: sharan12 (sharan12-rowan-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.20.1
# wandb: Run data is saved locally in /content/xvr/wandb/run-20250625_135917-wdml1yof
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run patient_se000002_longtrain
# wandb: ⭐️ View project at https://wandb.ai/sharan12-rowan-university/pose_regression
# wandb: 🚀 View run at https://wandb.ai/sharan12-rowan-university/pose_regression/runs/wdml1yof
# Reading CTs...: 100% 1/1 [00:05<00:00,  5.00s/it]
# ...
